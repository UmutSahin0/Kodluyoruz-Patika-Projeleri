# %% [markdown]
# # Binary Search Tree

# %% [markdown]
# ## Soru

# %% [markdown]
# [7, 5, 1, 8, 3, 6, 0, 9, 4, 2] dizisinin Binary-Search-Tree aşamaları

# %% [markdown]
# ### Çözüm

# %% [markdown]
# ![image.png](attachment:1f0be5fc-a8a2-461f-8f24-03cd460e549e.png)
